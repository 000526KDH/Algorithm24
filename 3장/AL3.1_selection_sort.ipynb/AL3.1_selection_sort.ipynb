# %% [markdown]
# 선택정렬

# %% [markdown]
# 1)문제정의
# 문제이름 : 선택 정렬 알고리즘
# 문제설명 : 정렬 안 된 리스트들을 진행과정을 보면서 정렬된 리스트로 만든다

# %% [markdown]
# 2)알고리즘 설명
# 명칭 : 제자리 정렬을 위한 알고리즘
# 입력 : 정렬 안 된 리스트
# 출력 : 정렬된 리스트
# 처리순서 : 입력 리스트에서 가장 작은 항목을 찾고,이것을 꺼내 정렬된 리스트에 순서대로 저장한다.

# %% [markdown]
# 3)손으로 푼 예제
# ![alt text](image.png)

# %% [markdown]
# 4)알고리즘 개요(입력 변수,출력,알고리즘 개요)
# def selection_sort(A):              #선택 정렬
#     n=len(A)                        #n:리스트 A의 길이
#     for i in range(n-1):            #0,1,2,... n-2[외부 루프]
#         least=i
#         for j in range(i+1,n):      #i+1,...n-1[내부 루프]
#             if(A[j]<A[least]):      #비교연산
#                 least = j           #최소항목 갱신
#         A[i],A[least]=A[least],A[i]  #배열 항목 교환
#         printStep(A,i+1)            #중간 과정 출력용 문장
#
# def printStep(arr,val):             #중간 과정 출력용 함수
#     print("Step%2d= "% val,end='')  #현재 단계를 출력
#     print(arr)                      #리스트의 내용을 출력

# %% [markdown]
# 5)알고리즘코드(PY,C)
# def selection_sort(A):
#     n=len(A)
#     for i in range(n-1):
#         least=i
#         for j in range(i+1,n):
#             if(A[j]<A[least]):
#                 least = j
#         A[i],A[least]=A[least],A[i]
#         printStep(A,i+1)
#
# def printStep(arr,val):
#     print("Step%2d= "% val,end='')
#     print(arr)

# %% [markdown]
# 6)테스트 코드(PY,C)
# def selection_sort(A):
#     n=len(A)
#     for i in range(n-1):
#         least=i
#         for j in range(i+1,n):
#             if(A[j]<A[least]):
#                 least = j
#         A[i],A[least]=A[least],A[i]
#         printStep(A,i+1)
#
# def printStep(arr,val):
#     print("Step%2d= "% val,end='')
#     print(arr)
#
# data=[5,3,8,4,9,1,6,2,7]
# print("Original :",data)
# selection_sort(data)
# print("Selection :",data)

# %% [markdown]
# 7)수행 결과(MD,결과 캡쳐하여 이미지로 삽입)
# ![image.png](attachment:image.png)

# %% [markdown]
# 8)복잡도 분석(MD)
# ![image.png](attachment:image.png)

# %% [markdown]
# 9)조별 협력 내용
