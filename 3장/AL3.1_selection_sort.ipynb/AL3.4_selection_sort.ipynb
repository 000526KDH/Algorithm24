# %% [markdown]
# 최근접 쌍의 거리 문제

# %% [markdown]
# #1)문제정의
# 문제이름 : 최근접 쌍의 거리 문제
# 문제설명 : 가장 가까운 쌍의 거리를 구하기
# #2)알고리즘 설명
# 억지기법을 사용하여 무식한 방법으로 찾아낸다.
#
#
# #3)손으로 푼 예제
# ![스크린샷 2024-04-16 133849.png](<attachment:스크린샷 2024-04-16 133849.png>)
#
#
#
# #4)알고리즘 개요(입력 변수,출력,알고리즘 개요)
# 이중 반복문을 사용해 모든 점의 쌍의 거리를 계산하여 최소 거리를 계산후 return 받은 함수들을 각각 최소거리,최근접 점들의 쌍 중 첫 번째 점p[i]와 p[j]를 반환하여 출력한다.

# %% [markdown]
# #5)알고리즘코드(PY,C)
# def closest_pair(p):
#     n=len(p)
#     mindist=float("inf")
#     for i in range(n-1):
#         for j in range(i+1,n):
#             dist = distance(p[i],p[j])
#             if dist < mindist:
#                 mindist = dist
#     return mindist
#
# import math
# def distance(p1,p2):
#     return math.sqrt((p1[0]-p2[0])**2+(p1[1]-p2[1])**2)
#
# p=[(2,3),(12,30),(40,50),(5,1),(12,10),(3,4)]
# print("최근접 거리:",closest_pair(p))
#
# 6)테스트 코드(PY,C)
# import math
# def distance(p1,p2):
#     return math.sqrt((p1[0]-p2[0])**2+(p1[1]-p2[1])**2)
#
# def closest_pair(p):
#     minp1=[0,0]
#     minp2=[0,0]
#     n=len(p)
#     mindist=float("inf")
#     for i in range(n-1):
#         for j in range(i+1,n):
#             dist = distance(p[i],p[j])
#             if dist < mindist:
#                 mindist = dist
#                 minp1=p[i]
#                 minp2=p[j]
#     return mindist,minp1,minp2
#
# p=[(2,3),(12,30),(40,50),(5,1),(12,10),(3,4)]
#
# mindist,minp1,minp2=closest_pair(p)
# print("최근접 거리:",mindist)
# print("p1의 값 :",minp1)
# print("p2의 값: ",minp2)
#
# 7)수행 결과(MD,결과 캡쳐하여 이미지로 삽입)
# ![스크린샷 2024-04-16 133849.png](<attachment:스크린샷 2024-04-16 133849.png>)
# 8)복잡도 분석(MD)
